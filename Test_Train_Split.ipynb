# %% [markdown]
# <a href="https://colab.research.google.com/github/Habeeb239/ML-and-DL/blob/main/Test_Train_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/carprices (1).csv")
df.tail()
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Mileage'].plot(kind='hist', bins=20, title='Mileage')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age(yrs)'].plot(kind='hist', bins=20, title='Age(yrs)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Sell Price($)'].plot(kind='hist', bins=20, title='Sell Price($)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
x = df.drop('Sell Price($)',axis=1)
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
cls = LinearRegression()

# %%
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
cls.predict(x_test)
# Out:
# array([18063.96046043, 21921.80292804, 37675.03107659, 26423.36195186])

# %%
y_test
# Out:
# 11    19500
# 0     18000
# 16    35500
# 2     26100
# Name: Sell Price($), dtype: int64

# %%
cls.score(x_test,y_test)
# Out:
# 0.8830593498855253
